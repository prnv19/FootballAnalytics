# %%
import pandas as pd
import numpy as np
import os
import ftfy

# %%
df = pd.read_csv('Data/player_stats.csv')
df.head()
# Out:
#        id             name   dateOfBirth   Age Height   Foot        Position  \
# 0  591949     Aaron Hickey  Jun 10, 2002  22.0  1,85m   both      Right-Back
# 1  434207   Aaron Connolly  Jan 28, 2000  25.0  1,74m  right  Centre-Forward
# 2  578459  Aaron Bastiaans   Apr 4, 2002  22.0  1,84m  right     Left Winger
# 3  884244      AJ Marcucci  Jul 31, 1999  25.0  1,91m    NaN      Goalkeeper
# 4  401362   AarÃ³n Herrera   Jun 6, 1997  27.0  1,80m  right      Right-Back
#
#                         OtherPosition       National  MarketValue  ...   25MP  \
# 0      ['Left-Back', 'Left Midfield']       Scotland   22000000.0  ...    0.0
# 1                  ['Second Striker']        Ireland    2500000.0  ...  505.0
# 2  ['Right Winger', 'Centre-Forward']    Netherlands          0.0  ...    0.0
# 3                                  []  United States     250000.0  ...    0.0
# 4     ['Left-Back', 'Right Midfield']  United States    2000000.0  ...    0.0
#
#   25AP  Ranking     2020AvgMV     2021AvgMV   2022AvgMV     2023AvgMV  \
# 0    0  432.000  1.845000e+06  8.666667e+06  17000000.0  2.833333e+07
# 1   14    3.644  5.500000e+06  7.000000e+06   5500000.0  3.500000e+06
# 2    0    0.000  1.500000e+05  1.250000e+05    175000.0  0.000000e+00
# 3    0    0.000  0.000000e+00  1.000000e+05    125000.0  1.500000e+05
# 4    0    4.274  9.666667e+05  1.600000e+06   2000000.0  2.000000e+06
#
#       2024AvgMV  2025AvgMV  TotalCups
# 0  2.500000e+07        0.0          0
# 1  2.500000e+06        0.0          2
# 2  0.000000e+00        0.0          0
# 3  2.166667e+05        0.0          0
# 4  2.000000e+06        0.0          1
#
# [5 rows x 64 columns]

# %% [markdown]
# #### Handling missing values

# %%
#Check for misssing values in columns and store in df
missing = df.isnull().sum()
missing[missing > 0]
# Out:
# dateOfBirth          16
# Age                  16
# Height              196
# Foot                691
# Position             61
# National            239
# Outfitter         10330
# Club_name            16
# ContractExpiry       16
# ContractOption    12061
# dtype: int64

# %%
#Drop null columns
df.dropna(subset=['Height'], inplace=True)
df.dropna(subset=['Age'], inplace=True)
df.dropna(subset=['Club_name'], inplace=True)
df.dropna(subset=['Position'], inplace=True)
df.dropna(subset=['National'], inplace=True)


#Set foot as 'hand' for goalkeepers
df.loc[df['Position'] == 'Goalkeeper', 'Foot'] = 'hand'

#Find average values for foot using player position
foot_dict = df.groupby('Position')['Foot'].agg(lambda x: x.value_counts().index[0]).to_dict()
#Use the dictionary to fill in missing values
df['Foot'] = df.apply(lambda row: foot_dict[row['Position']] if pd.isnull(row['Foot']) else row['Foot'], axis=1)

missing = df.isnull().sum()
missing[missing > 0]
# Out:
# Outfitter          9894
# ContractOption    11630
# dtype: int64

# %% [markdown]
# #### Transforming data

# %%
#Fix player names
df['name'] = df['name'].apply(lambda x: ftfy.fix_text(x))
#Fix club names
df['Club_name'] = df['Club_name'].apply(lambda x: ftfy.fix_text(x))

#Convert age to int
df['Age'] = df['Age'].astype(int)

#Convert height to float
df['Height'] = df['Height'].str.replace(',', '.').str.replace('m', '').astype(float)

# %%
df
# Out:
#            id             name   dateOfBirth  Age  Height   Foot  \
# 0      591949     Aaron Hickey  Jun 10, 2002   22    1.85   both
# 1      434207   Aaron Connolly  Jan 28, 2000   25    1.74  right
# 2      578459  Aaron Bastiaans   Apr 4, 2002   22    1.84  right
# 3      884244      AJ Marcucci  Jul 31, 1999   25    1.91   hand
# 4      401362    Aarón Herrera   Jun 6, 1997   27    1.80  right
# ...       ...              ...           ...  ...     ...    ...
# 13400  344802   Simon Stefanec   Sep 5, 1998   26    1.78  right
# 13401  469686     Žan Kolmanič   Mar 3, 2000   24    1.78   left
# 13402  340427        Zan Celar  Mar 14, 1999   25    1.86  right
# 13403  180805        Zan Majer  Jul 25, 1992   32    1.80  right
# 13404  383774      Ziga Frelih   Feb 6, 1998   26    1.97   hand
#
#                  Position                                 OtherPosition  \
# 0              Right-Back                ['Left-Back', 'Left Midfield']
# 1          Centre-Forward                            ['Second Striker']
# 2             Left Winger            ['Right Winger', 'Centre-Forward']
# 3              Goalkeeper                                            []
# 4              Right-Back               ['Left-Back', 'Right Midfield']
# ...                   ...                                           ...
# 13400  Attacking Midfield               ['Left Winger', 'Right Winger']
# 13401           Left-Back               ['Left Midfield', 'Right-Back']
# 13402      Centre-Forward                               ['Left Winger']
# 13403    Central Midfield  ['Attacking Midfield', 'Defensive Midfield']
# 13404          Goalkeeper                                            []
#
#             National  MarketValue  ...     25MP 25AP  Ranking     2020AvgMV  \
# 0           Scotland   22000000.0  ...     0.00    0  432.000  1.845000e+06
# 1            Ireland    2500000.0  ...   505.00   14    3.644  5.500000e+06
# 2        Netherlands          0.0  ...     0.00    0    0.000  1.500000e+05
# 3      United States     250000.0  ...     0.00    0    0.000  0.000000e+00
# 4      United States    2000000.0  ...     0.00    0    4.274  9.666667e+05
# ...              ...          ...  ...      ...  ...      ...           ...
# 13400       Slovakia          0.0  ...     0.00    0    0.000  1.000000e+05
# 13401       Slovenia    1000000.0  ...     0.00    0    6.910  4.250000e+05
# 13402       Slovenia    4500000.0  ...  1134.00   22    2.226  7.625000e+05
# 13403       Slovenia     400000.0  ...   682.00   16    0.000  1.733333e+06
# 13404       Slovenia     450000.0  ...   481.53   22    0.000  1.500000e+05
#
#           2021AvgMV     2022AvgMV     2023AvgMV     2024AvgMV  2025AvgMV  \
# 0      8.666667e+06  1.700000e+07  2.833333e+07  2.500000e+07        0.0
# 1      7.000000e+06  5.500000e+06  3.500000e+06  2.500000e+06        0.0
# 2      1.250000e+05  1.750000e+05  0.000000e+00  0.000000e+00        0.0
# 3      1.000000e+05  1.250000e+05  1.500000e+05  2.166667e+05        0.0
# 4      1.600000e+06  2.000000e+06  2.000000e+06  2.000000e+06        0.0
# ...             ...           ...           ...           ...        ...
# 13400  1.250000e+05  1.125000e+05  0.000000e+00  0.000000e+00        0.0
